# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
#REVISED GRAPH 26/3/26 - more data points added, outlier removed (mistyped data)
#plot planetary radius as a function of equilibrium temperature
#data: temperature (K) and radius (Jupiter radii)
temperature = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])
radius = np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.326,1.685,1.433,1.56,1.039,1.164])

sort_indices = np.argsort(temperature)
sort_indices = np.argsort(radius)
temperature_sorted = temperature[sort_indices]
radius_sorted = radius[sort_indices]
plt.figure()
plt.scatter(temperature_sorted, radius_sorted)

plt.xlabel('Temperature (K)')
plt.ylabel('Planetary Radius (Jupiter Radii)')
plt.title('Planetary Radius as a Function of Equilibrium Temperature')
plt.show()

# %%
#CONTROL JUPITERS - to compare against hot jupiters
temp = np.array([717.6,552,400,629,738,530,759,434,651])
rad = np.array([0.762,0.368,0.904,0.330,0.223,0.282,1.055,1.11,0.448])
plt.scatter(temp,rad, color = 'red')
plt.xlim(0,2600)
plt.ylim(0,2)
plt.xlabel('Temperature (K)')
plt.ylabel('Planetary Radius (Jupiter Radii)')
plt.title('Planetary Radius as a Function of Equilibrium Temperature - Control Group')
plt.show()

# %%
#COMPARISON OF CONTROL GROUP VS HOT JUPITERS.
temperature = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])
radius = np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.326,1.685,1.433,1.56,1.039,1.164])

temp = np.array([717.6,552,400,629,738,530,759,434,651])
rad = np.array([0.762,0.368,0.904,0.330,0.223,0.282,1.055,1.11,0.448])

sort_indices = np.argsort(temperature)
sort_indices = np.argsort(radius)
temperature_sorted = temperature[sort_indices]
radius_sorted = radius[sort_indices]
plt.figure()
plt.scatter(temperature_sorted, radius_sorted, color = 'blue',label = 'Hot Jupiters')
plt.scatter(temp,rad, color = 'red',label = 'Control Group')

plt.xlabel('Temperature (K)')
plt.ylabel('Planetary Radius (Jupiter Radii)')
plt.title('Planetary Radius as a Function of Equilibrium Temperature')
plt.legend()
plt.show()

# %%
from scipy.optimize import curve_fit
temperature = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])
radius = np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.164,1.685,1.433,1.56,1.039,1.164])

temp = np.array([717.6,552,400,629,738,530,759,434,651])
rad = np.array([0.762,0.368,0.904,0.330,0.223,0.282,1.055,1.11,0.448])


hot_jupiter_sort_indices = np.argsort(temperature)
temperature_hot_jupiter_sorted = temperature[hot_jupiter_sort_indices]
radius_hot_jupiter_sorted = radius[hot_jupiter_sort_indices]

#line of best fit for Hot Jupiters
t_fit = np.polyfit(temperature_hot_jupiter_sorted, radius_hot_jupiter_sorted, 1)
t_fit_fn = np.poly1d(t_fit)


plt.scatter(temperature_hot_jupiter_sorted, radius_hot_jupiter_sorted, color = 'blue', label = 'Hot Jupiters')
plt.scatter(temp, rad, color = 'red', label = 'Control Group')

plt.plot(temperature_hot_jupiter_sorted, t_fit_fn(temperature_hot_jupiter_sorted), '--k', label=f'Hot Jupiters Fit: y = {t_fit[0]:.4f}x + {t_fit[1]:.4f}')

plt.xlabel('Temperature (K)')
plt.ylabel('Planetary Radius (Jupiter Radii)')
plt.title('Planetary Radius as a Function of Equilibrium Temperature')
plt.legend()
plt.show()

# %%
#PLOT OF PLANET MASS VS RADIUS
#are there any correlations between these and temperature?

mass=np.array([1.855,3.47,9.28,1.31,6.1,9.7,1.47,1.42,3.91,3.88,3.57,0.281,3.7,1.7,2.48,6.01,4.22,0.709,1.339,1.45,1.366,1.94,0.579,0.73])
radius=np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.326,1.685,1.433,1.56,1.039,1.164])
plt.scatter(radius,mass)
plt.ylabel('Mass (Jupiter Masses)')
plt.xlabel('Radius (Jupiter Radii)')
plt.title('Radius vs. Mass')
plt.show()

# %%
mass=np.array([1.855,3.47,9.28,1.31,6.1,9.7,1.47,1.42,3.91,3.88,3.57,0.281,3.7,1.7,2.48,6.01,4.22,0.709,1.339,1.45,1.366,1.94,0.579,0.73])
radius=np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.326,1.685,1.433,1.56,1.039,1.164])
temperature = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])

sort_indices = np.argsort(temperature)
sort_indices = np.argsort(radius)
sort_indices = np.argsort(mass)
temperature_sorted = temperature[sort_indices]
radius_sorted = radius[sort_indices]
mass_sorted = mass[sort_indices]

fig,ax = plt.subplots(figsize=(8,6))
scatter = ax.scatter(radius_sorted,mass_sorted,c=temperature_sorted, cmap='Greens', s =60)
cbar = fig.colorbar(scatter, ax=ax)
cbar.set_label('Temperature (K)')

ax.set_ylabel('Mass (Jupiter Masses)')
ax.set_xlabel('Radius (Jupiter Radii)')
ax.set_title('Mass vs. Radius vs. Temperature')

plt.show()

# %%
#calculating the incidence flux of a planet based off of its equilibrium temperature
#s is a substitute for Stefan - Boltzmann constant, W m-2 K-4
#Temperaure is in kelvin (K)
#A_b is bond albedo, amount of light reflected
#incidence flux in W/m^2

s = 5.670374419e-8
T = 2530
A_b = 0.064
flux = (4 * s * T**4) / (1 - A_b)
print(flux)
# Out:
# 9928370.235408127

# %%
#multiple answers for flux
#assume A_b is 0.3
radius=np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.326,1.685,1.433,1.56,1.039,1.164])
T = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])
s = 5.670374419e-8
A_b = 0.3
flux = (4 * s * T**4) / (1 - A_b)
print(flux)

plt.scatter(radius,flux)
plt.ylabel('Incident Flux (W/m^2)')
plt.xlabel('Radius (Jupiter Radii)')
plt.title('Radius vs. Flux')
plt.show()
# Out:
# [  791067.85979353  1230595.60893593 13700436.67492615  2355408.83140657
#   1192264.96293629   869788.31020286 13275649.34334572  2287305.13808322
#   5733718.0009405    667422.67941477  1798900.76794538   547259.22776995
#  14670792.51166317  2803045.74537795    91012.11463992   628205.47511029
#   2526268.38723684  2990633.79310635   877971.2877693   7494250.65674787
#   3101966.08910371  3524009.45268261   638920.89201966  1464211.40007487]

# %%
#multiple answers for flux
#assume A_b is 0.3
radius=np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.326,1.685,1.433,1.56,1.039,1.164])
T = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])
s = 5.670374419e-8
A_b = 0.3
flux = (4 * s * T**4) / (1 - A_b)
print(flux)

plt.scatter(T,flux)
plt.ylabel('Incident Flux (W/m^2)')
plt.xlabel('Equilibrium Temperature (K)')
plt.title('Equilibrium Temperature vs. Flux')
plt.show()
# Out:
# [  791067.85979353  1230595.60893593 13700436.67492615  2355408.83140657
#   1192264.96293629   869788.31020286 13275649.34334572  2287305.13808322
#   5733718.0009405    667422.67941477  1798900.76794538   547259.22776995
#  14670792.51166317  2803045.74537795    91012.11463992   628205.47511029
#   2526268.38723684  2990633.79310635   877971.2877693   7494250.65674787
#   3101966.08910371  3524009.45268261   638920.89201966  1464211.40007487]

# %%
radius=np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.326,1.685,1.433,1.56,1.039,1.164])
temperature = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])
s = 5.670374419e-8
A_b = 0.3
flux = (4 * s * T**4) / (1 - A_b)
print(flux)


fig,ax = plt.subplots()
scatter = ax.scatter(radius,flux,c=temperature, cmap='Greens', s =60)
cbar = fig.colorbar(scatter, ax=ax)
cbar.set_label('Temperature (K)')

ax.set_ylabel('Incident Flux (W/m^2)')
ax.set_xlabel('Radius (Jupiter Radii)')


plt.show()
# Out:
# [  791067.85979353  1230595.60893593 13700436.67492615  2355408.83140657
#   1192264.96293629   869788.31020286 13275649.34334572  2287305.13808322
#   5733718.0009405    667422.67941477  1798900.76794538   547259.22776995
#  14670792.51166317  2803045.74537795    91012.11463992   628205.47511029
#   2526268.38723684  2990633.79310635   877971.2877693   7494250.65674787
#   3101966.08910371  3524009.45268261   638920.89201966  1464211.40007487]

# %%
#assume A_b is 0.3
radius=np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.326,1.685,1.433,1.56,1.039,1.164])
T = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])
s = 5.670374419e-8
A_b = 0.3
flux = (4 * s * T**4) / (1 - A_b)
print(flux)


t_fit_flux = np.polyfit(radius, flux, 1)
t_fit_fn_flux = np.poly1d(t_fit_flux)

plt.scatter(radius,flux)
plt.plot(radius, t_fit_fn_flux(radius), '--k', label=f'Fit: y = {t_fit_flux[0]:.2f}x + {t_fit_flux[1]:.2f}')

plt.ylabel('Incident Flux (W/m^2)')
plt.xlabel('Radius (Jupiter Radii)')
plt.title('Radius vs. Flux')
plt.legend()
plt.show()
# Out:
# [  791067.85979353  1230595.60893593 13700436.67492615  2355408.83140657
#   1192264.96293629   869788.31020286 13275649.34334572  2287305.13808322
#   5733718.0009405    667422.67941477  1798900.76794538   547259.22776995
#  14670792.51166317  2803045.74537795    91012.11463992   628205.47511029
#   2526268.38723684  2990633.79310635   877971.2877693   7494250.65674787
#   3101966.08910371  3524009.45268261   638920.89201966  1464211.40007487]

# %%
#observational uncertainties
temperature = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])
radius = np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.164,1.685,1.433,1.56,1.039,1.164])

temp = np.array([717.6,552,400,629,738,530,759,434,651])
rad = np.array([0.762,0.368,0.904,0.330,0.223,0.282,1.055,1.11,0.448])


hot_jupiter_sort_indices = np.argsort(temperature)
temperature_hot_jupiter_sorted = temperature[hot_jupiter_sort_indices]
radius_hot_jupiter_sorted = radius[hot_jupiter_sort_indices]

#line of best fit for Hot Jupiters
t_fit = np.polyfit(temperature_hot_jupiter_sorted, radius_hot_jupiter_sorted, 1)
t_fit_fn = np.poly1d(t_fit)

#uncertainties
radius_uncertainty = np.array([0.05])
temperature_uncertainty = np.array([20])

plt.errorbar(temperature_hot_jupiter_sorted, radius_hot_jupiter_sorted, xerr=temperature_uncertainty, yerr=radius_uncertainty, fmt='o', color='blue', label='Hot Jupiters')

plt.scatter(temperature_hot_jupiter_sorted, radius_hot_jupiter_sorted, color = 'blue', label = 'Hot Jupiters')
plt.scatter(temp, rad, color = 'red', label = 'Control Group')

plt.plot(temperature_hot_jupiter_sorted, t_fit_fn(temperature_hot_jupiter_sorted), '--k', label=f'Hot Jupiters Fit: y = {t_fit[0]:.4f}x + {t_fit[1]:.4f}')

plt.xlabel('Temperature (K)')
plt.ylabel('Planetary Radius (Jupiter Radii)')
plt.title('Planetary Radius as a Function of Equilibrium Temperature')
plt.legend()
plt.show()

# %%
#multiple answers for flux
#assume A_b is 0.3
radius=np.array([1.302,1.31,1.512,1.74,1.135,1.13,1.965,1.25,1.586,1.099,1.466,1.279,1.597,1.35,1.22,1.091,1.11,1.373,1.326,1.685,1.433,1.56,1.039,1.164])
T = np.array([1250,1396,2550,1642,1385,1280,2530,1630,2051,1198,1535,1140,2594,1715,728,1180,1671,1743,1283,2193,1759,1816,1185,1458])
s = 5.670374419e-8
A_b = 0.3
flux = (4 * s * T**4) / (1 - A_b)
print(flux)

#uncertainties
#each temperature uncertainty is different. Becuase of this, I made the generalisation that all eq. temp uncertainties are 5% (same as radius)
#becuase of this, the uncertaintiy in flux will be 20% (carried error in temp uncertainty).
#the flux uncertainty will also depend on bond albedo, but this data is not available.

flux_uncertainty = 0.2 * flux
temperature_uncertainty = np.array([0.05])
radius_uncertainty = np.array([0.05])

plt.errorbar(radius, flux, xerr=radius_uncertainty, yerr=flux_uncertainty, fmt='o', color='blue', label='Hot Jupiters w/ uncertainty')

plt.scatter(radius,flux)
plt.ylabel('Incident Flux (W/m^2)')
plt.xlabel('Radius (Jupiter Radii)')
plt.title('Radius vs. Flux')
plt.legend()
plt.show()
# Out:
# [  791067.85979353  1230595.60893593 13700436.67492615  2355408.83140657
#   1192264.96293629   869788.31020286 13275649.34334572  2287305.13808322
#   5733718.0009405    667422.67941477  1798900.76794538   547259.22776995
#  14670792.51166317  2803045.74537795    91012.11463992   628205.47511029
#   2526268.38723684  2990633.79310635   877971.2877693   7494250.65674787
#   3101966.08910371  3524009.45268261   638920.89201966  1464211.40007487]
